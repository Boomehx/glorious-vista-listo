# %%
import pandas as pd
import numpy as npy

# %%
df = pd.read_csv("https://docs.google.com/spreadsheets/d/1yiTNYyfjpvOmbg1_YBhTFs4vp-f8Mcc5vBoMf0a2skI/export?format=csv")
df
print("Hi")
# Out:
#        date  rank  rankCredits  listoCredits distNameATK distNameDEF  \
# 0  01/01/24     3          100            20       NILLS       KEONS
# 1  02/01/24     4          130            30        NICO       ANDRE
# 2  03/01/24     5          145            15       KEONS        NICO
# 3  04/01/24     4          170            25       ANDRE       NILLS
# 4  05/01/24     2          210            40    SACARVER      LISDEN
# 5  06/01/24     1          270            60      VETOMO     REISDRO
# 6  07/01/24     3          275             5       NILLS        NICO
# 7  08/01/24     4          282             7      LISDEN       KEONS
# 8  09/01/24     6          325            43     REISDRO      VETOMO
# 9  10/01/24     7          367            42       KEONS    SACARVER
#
#    creditsGiven  listoQrtATK  listoQrtDEF  creditsATK  creditsDEF  distQrtATK  \
# 0            20            1            1           5           5           2
# ...

# %%
#keonsATKRank = df[(df["distNameATK"] == "KEONS")|(df["distNameDEF"] == "KEONS")]["rank"].mode()
#print(keonsATKRank.to_string(index=False))

# %%
#keonsDEFmode = df[(df["distNameDEF"] == "KEONS")]["distQrtDEF"].mode()
#print(keonsDEFmode)

# %%
filtered_df = df.loc[(df['date'] >= '01/01/24') & (df['date'] < '04/01/24')]
keonsDEFmode = filtered_df[(filtered_df["distNameDEF"] == "KEONS")]["distQrtDEF"].mode()
print(keonsDEFmode)
# Out:
# 0    1
# Name: distQrtDEF, dtype: int64

# %%
def modeQrtDEF(district, startDate = False):
    return "Hi"

modeQrtDEF("KEONS")
# Out:
# 'Hi'
